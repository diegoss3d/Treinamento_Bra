# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Ler e exibir um arquivo CSV usando pandas

# %%
df = spark.read.csv('/FileStore/tables/retail.csv', sep=';', header=True)
df = df.toPandas()

# %% [markdown]
# ### 2. Selecionar colunas específicas de um DataFrame usando pandas

# %%
df[["stock_code", "unit_price"]].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stock_code</th>
#       <th>unit_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>85123A</td>
#       <td>2,55</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>71053</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>84406B</td>
#       <td>2,75</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>84029G</td>
#       <td>3,39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>84029E</td>
#       <td>3,39</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 3. Filtrar linhas com base em uma condição usando pandas

# %%
df[df['unit_price'] > '5'].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#       <th>region</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>536365</td>
#       <td>22752</td>
#       <td>SET 7 BABUSHKA NESTING BOXES</td>
#       <td>2</td>
#       <td>01/12/2010 08:26</td>
#       <td>7,65</td>
#       <td>17850</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>536367</td>
#       <td>22622</td>
#       <td>BOX OF VINTAGE ALPHABET BLOCKS</td>
#       <td>2</td>
#       <td>01/12/2010 08:34</td>
#       <td>9,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>536367</td>
#       <td>21754</td>
#       <td>HOME BUILDING BLOCK WORD</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>5,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>536367</td>
#       <td>21755</td>
#       <td>LOVE BUILDING BLOCK WORD</td>
#       <td>3</td>
#       <td>01/12/2010 08:34</td>
#       <td>5,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>536367</td>
#       <td>21777</td>
#       <td>RECIPE BOX WITH METAL HEART</td>
#       <td>4</td>
#       <td>01/12/2010 08:34</td>
#       <td>7,95</td>
#       <td>13047</td>
#       <td>United Kingdom</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 4. Agrupar dados com base em uma coluna usando pandas

# %%
# df.groupby('A').agg({'B': ['min', 'max'], 'C': 'sum'})
df.groupby('region').count().head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>invoice_no</th>
#       <th>stock_code</th>
#       <th>description</th>
#       <th>quantity</th>
#       <th>invoice_date</th>
#       <th>unit_price</th>
#       <th>customer_id</th>
#     </tr>
#     <tr>
#       <th>region</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Australia</th>
#       <td>1259</td>
#       <td>1259</td>
#       <td>1259</td>
#       <td>1259</td>
#       <td>1259</td>
#       <td>1259</td>
#       <td>1259</td>
#     </tr>
#     <tr>
#       <th>Austria</th>
#       <td>401</td>
#       <td>401</td>
#       <td>401</td>
#       <td>401</td>
#       <td>401</td>
#       <td>401</td>
#       <td>401</td>
#     </tr>
#     <tr>
#       <th>Bahrain</th>
#       <td>19</td>
#       <td>19</td>
#       <td>19</td>
#       <td>19</td>
#       <td>19</td>
#       <td>19</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>Belgium</th>
#       <td>2069</td>
#       <td>2069</td>
#       <td>2069</td>
#       <td>2069</td>
#       <td>2069</td>
#       <td>2069</td>
#       <td>2069</td>
#     </tr>
#     <tr>
#       <th>Brazil</th>
#       <td>32</td>
#       <td>32</td>
#       <td>32</td>
#       <td>32</td>
#       <td>32</td>
#       <td>32</td>
#       <td>32</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 5. Usar a função max em alguma coluna do DataFrame

# %%
df['unit_price'].max()
# Out:
# Out[29]: '99,96'
